# %%
from CATH_parser import *
from pprint import pprint
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import re
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("./parsed_list.txt", sep='\t',index_col=0)
df = df.dropna()
df['COMMENT'] = np.nan

# %%
acronRegex = re.compile(r'\w*[A-Z]\w*[A-Z]\w*|C-[T|t]erminal|N-[T|t]erminal')

# %%
new_column = pd.Series()
for sfam in df.itertuples():
    l = sfam.NAME.split()
    new_name = [l[0]]
    for word in l[1:]:
        if acronRegex.search(word):
            new_name.append(word)
        else:
            new_name.append(word.lower())
    new_column[sfam.Index] = " ".join(new_name)

# %%
new_column[new_column != df['NAME']]
# Out:
# 1.10.8.110        Photosystem i PsaF, reaction centre subunit III
# 1.10.8.160                                DNA primase s; domain 2
# 1.10.8.190      Carbon monoxide dehydrogenase alpha subunit. c...
# 1.10.10.10      Winged helix-like DNA-binding domain superfami...
# 1.10.10.250              Ribosomal protein l11, C-terminal domain
# 1.10.10.430         Phosphatase 2c, C-terminal domain suprefamily
# 1.10.10.460                            Ribonuclease hii. domain 2
# 1.10.10.510                Zinc finger, large t-antigen d1 domain
# 1.10.10.520     Ubiquitin activating enzymes (uba3). chain: b,...
# 1.10.10.530                    mam-mhc complex, chain d, domain 2
# 1.10.10.570     Winged helix DNA-binding domain. chain c. doma...
# 1.10.10.580       Structural maintenance of chromosome 1. chain e
# 1.10.10.650                                    RuvA domain 2-like
# 1.10.10.660     conserved protein of unknown function from ent...
# 1.10.10.670     photosystem ii from thermosynechococcus elongatus
# 1.10.10.680     Hypothetical protein VC1899 (restriction endon...
# 1.10.10.750                           Ypt/Rab-GAP domain of gyp1p
# 1.10.10.760              E-set domains of sugar-utilizing enzymes
# 1.10.12.10         Lyase 2-enoyl-coa hydratase, chain a, domain 2
# 1.10.20.10                                     Histone, subunit a
# 1.10.45.10            Vanillyl-alcohol oxidase; chain a, domain 4
# 1.10.60.20                            Ribosomal protein s17e-like
# 1.10.140.10                          MET apo-repressor, subunit a
# 1.10.150.50                           Transcription factor, ets-1
# 1.10.150.290    S-adenosyl-L-methionine-dependent methyltransf...
# 1.10.150.320              Photosystem II 12 kda extrinsic protein
# 1.10.167.10         Regulator of g-protein signalling 4, domain 2
# 1.10.170.10              Bluetongue virus 10, subunit 1, domain 3
# 1.10.189.10                 Pyruvate phosphate dikinase, domain 2
# 1.10.220.50     Bacteriophage t4, gp59, helicase assembly prot...
#                                       ...
# 4.10.420.10                                Smk toxin, alpha chain
# 4.10.450.10                             Glucose oxidase, domain 2
# 4.10.460.10        Inositol polyphosphate 1-phosphatase, domain 1
# 4.10.470.10                           Ricin (a subunit), domain 2
# 4.10.510.10     Pyruvoyl-Dependent histidine decarboxylas, sub...
# 4.10.530.10     Gamma-fibrinogen carboxyl terminal fragment, d...
# 4.10.540.10     Photosynthetic reaction centre, h subunit, N-t...
# 4.10.640.10                                 Ribosomal protein s18
# 4.10.670.10         Cholecystokinin a receptor, N-terminal domain
# 4.10.690.10                 Cricket paralysis virus, vp4; chain d
# 4.10.710.10             Hepatitis c virus capsid protein; chain a
# 4.10.720.10     Smad anchor for receptor activation, smad-bind...
# 4.10.740.10                                 Coagulation factor IX
# 4.10.770.10              Signal protein aml-1b; chain a, domain 3
# 4.10.790.10          Pyruvate-ferredoxin oxidoreductase; domain 7
# 4.10.810.10                    Virus scaffolding protein; chain a
# 4.10.830.10                    30s ribosomal protein s14; chain n
# 4.10.860.20                         Rabenosyn, rab binding domain
# 4.10.870.10                   Endo-1,4-beta-glucanase f. domain 3
# 4.10.880.10     Poliovirus 3d polymerase domain 1 (nucleotidyl...
# 4.10.900.10                     TCF3-CBD (catenin binding domain)
# 4.10.950.10                        Ribosomal protein l2, domain 3
# 4.10.960.10                        Ribosomal protein l3, domain 3
# 4.10.1030.10                           Ring box chain a; domain 5
# 4.10.1110.10                                 AN1-like zinc finger
# 4.10.1190.10                      Chlorophyll a-b binding protein
# 4.10.1250.10                      Aminomethyltransferase fragment
# 4.10.1260.10    Scaffolding protein gpd of bacteriophage proca...
# 4.10.1310.10                     Dinoflagellate luciferase repeat
# 4.10.1330.10          non globular virulence effector SptP domain
# Length: 652, dtype: object

# %%
df[df['NAME'].str.contains("Protein")]
# Out:
#                S35_REPS  DOMAINS  \
# # CATH_ID
# 1.10.375.10           8      213
# 1.10.569.10           2       30
# 1.10.599.10           2       10
# 1.10.740.10           1        9
# 1.10.1050.10          2      330
# 1.10.1170.10         10      262
# 1.10.2040.10          1        3
# 1.10.2050.10          2       13
# 1.10.4180.10          1        1
# 1.20.89.10            1       85
# 1.20.1270.150         1        2
# 1.20.1440.30          2        4
# 1.25.40.120           4      153
# 2.10.110.10          29       97
# 2.30.27.10            3       14
# 2.30.110.10          73      345
# 2.40.200.10           1       14
# 2.40.240.10          10      319
# 2.40.320.10           9       61
# 2.60.40.1700          1       35
# 2.60.210.10           7      138
# 2.60.500.10           1        2
# 2.170.150.10          4       21
# 3.10.100.10          50      835
# 3.10.105.10          24      223
# 3.10.620.10           1        2
# 3.20.20.410           2        4
# 3.20.90.10            1        7
# 3.30.310.10          10      176
# 3.30.380.10           4      230
# 3.30.740.10           1       79
# 3.30.860.10           1      332
# 3.30.890.10           4       15
# 3.30.930.10          61      825
# 3.30.1570.10          1        3
# 3.40.366.10          16       89
# 3.40.395.10           4       66
# 3.40.1540.10          1        1
# 3.55.20.10            1        2
# 3.90.39.10            1       19
# 3.90.76.10           12      135
# 3.90.190.10          50      709
# 3.90.198.10           1        4
# 3.90.249.10           1       19
# 3.90.350.10           1        9
# 3.90.450.1            1        7
# 3.90.550.10          68     1150
# 3.90.830.10           3       29
# 3.90.1360.10          1        5
# 3.90.1370.10          1        3
# 4.10.6.10             1        1
# 4.10.110.10           4       38
# 4.10.210.10           1        2
# 4.10.710.10           1        1
# 4.10.770.10           1        1
# 4.10.810.10           2        3
# 4.10.830.10           2      311
#
#                                                             NAME  COMMENT
# # CATH_ID
# 1.10.375.10    Human Immunodeficiency Virus Type 1 Capsid Pro...      NaN
# 1.10.569.10    Aldehyde Ferredoxin Oxidoreductase Protein, su...      NaN
# 1.10.599.10    Aldehyde Ferredoxin Oxidoreductase Protein, su...      NaN
# 1.10.740.10        Transferase Inhibitor Protein From Tn5; Chain      NaN
# 1.10.1050.10    Ribosomal Protein S4 Delta 41; Chain A, domain 1      NaN
# 1.10.1170.10   Inhibitor Of Apoptosis Protein (2mihbC-IAP-1);...      NaN
# 1.10.2040.10                     Protein mu-1, chain B, domain 2      NaN
# 1.10.2050.10                     Protein mu-1, chain B, domain 3      NaN
# 1.10.4180.10                                       Protein LEAFY      NaN
# 1.20.89.10     Nitrogenase Molybdenum-iron Protein, subunit B...      NaN
# 1.20.1270.150                             Surface Active Protein      NaN
# 1.20.1440.30                         Biosynthetic Protein domain      NaN
# 1.25.40.120                          Protein prenylyltransferase      NaN
# 2.10.110.10                                Cysteine Rich Protein      NaN
# 2.30.27.10     Phage FD Coat Protein,Membrane penetration domain      NaN
# 2.30.110.10     Electron Transport, Fmn-binding Protein; Chain A      NaN
# 2.40.200.10         Telomere-binding Protein Beta Subunit; Chain      NaN
# 2.40.240.10                       Ribosomal Protein L25; Chain P      NaN
# 2.40.320.10                  Hypothetical Protein Pfu-838710-001      NaN
# 2.60.40.1700          Protein-arginine deiminase, central domain      NaN
# 2.60.210.10    Apoptosis, Tumor Necrosis Factor Receptor Asso...      NaN
# 2.60.500.10                        Surface Active Protein domain      NaN
# 2.170.150.10   Metal Binding Protein, Guanine Nucleotide Exch...      NaN
# 3.10.100.10                 Mannose-Binding Protein A, subunit A      NaN
# 3.10.105.10                  Dipeptide-binding Protein; Domain 3      NaN
# 3.10.620.10    Protein N-terminal glutamine amidohydrolase, a...      NaN
# 3.20.20.410                  Protein of unknown function UPF0759      NaN
# 3.20.90.10                                Tubby Protein; Chain A      NaN
# 3.30.310.10                                 TATA-Binding Protein      NaN
# 3.30.380.10                               MS2 Viral Coat Protein      NaN
# 3.30.740.10    Protein Inhibitor Of Neuronal Nitric Oxide Syn...      NaN
# 3.30.860.10                   30s Ribosomal Protein S19; Chain A      NaN
# 3.30.890.10                Methyl-cpg-binding Protein 2; Chain A      NaN
# 3.30.930.10                  Bira Bifunctional Protein; Domain 2      NaN
# 3.30.1570.10   Protein-tyrosine phosphatase, YopH, N-terminal...      NaN
# 3.40.366.10    Malonyl-Coenzyme A Acyl Carrier Protein, domain 2      NaN
# 3.40.395.10                       Adenoviral Proteinase; Chain A      NaN
# 3.40.1540.10   Protein of unknown function DUF1780, putative ...      NaN
# 3.55.20.10     Protein-L-isoaspartyl O-methyltransferase, C-t...      NaN
# 3.90.39.10              Hexon Major Viral Coat Protein, domain 2      NaN
# 3.90.76.10                   Dipeptide-binding Protein; Domain 1      NaN
# 3.90.190.10             Protein tyrosine phosphatase superfamily      NaN
# 3.90.198.10    Replication Fork Single-Stranded Dna Binding P...      NaN
# 3.90.249.10             Hexon Major Viral Coat Protein, domain 3      NaN
# 3.90.350.10    Transposase Inhibitor Protein From Tn5; Chain ...      NaN
# 3.90.450.1                          Minor Coat Protein; Domain 2      NaN
# 3.90.550.10    Spore Coat Polysaccharide Biosynthesis Protein...      NaN
# 3.90.830.10        Syntaxin Binding Protein 1; Chain A, domain 2      NaN
# 3.90.1360.10         Protein-glutamine gamma-glutamyltransferase      NaN
# 3.90.1370.10                     Protein mu-1, chain B, domain 1      NaN
# 4.10.6.10      Fusion Protein Of Alpha-na,k-atpase With Gluta...      NaN
# 4.10.110.10                        Spasmolytic Protein, domain 1      NaN
# 4.10.210.10              Transactivator Protein (TAT, TAT EIAVY)      NaN
# 4.10.710.10            Hepatitis C Virus Capsid Protein; Chain A      NaN
# 4.10.770.10             Signal Protein Aml-1b; Chain A, domain 3      NaN
# 4.10.810.10                   Virus Scaffolding Protein; Chain A      NaN
# 4.10.830.10                   30s Ribosomal Protein S14; Chain N      NaN

# %%
df.loc['4.10.770.10']
# Out:
# S35_REPS                                           1
# DOMAINS                                            1
# NAME        Signal Protein Aml-1b; Chain A, domain 3
# COMMENT                                          NaN
# Name: 4.10.770.10, dtype: object

# %%
new_column
# Out:
# 1.10.8.10            DNA helicase RuvA subunit, C-terminal domain
# 1.10.8.20       N-terminal domain of phosphatidylinositol tran...
# 1.10.8.40                                  Albumin-binding domain
# 1.10.8.110        Photosystem i PsaF, reaction centre subunit III
# 1.10.8.140                                             PDCD5-like
# 1.10.8.160                                DNA primase s; domain 2
# 1.10.8.190      Carbon monoxide dehydrogenase alpha subunit. c...
# 1.10.8.200      Replisome organizer (g39p helicase loader/inhi...
# 1.10.8.210                 Sirohaem synthase, dimerisation domain
# 1.10.8.240                                       CofD-like domain
# 1.10.8.250            DNA polymerase III clamp loader domain like
# 1.10.8.260                              HI0933 insert domain-like
# 1.10.8.270      putative rabgap domain of human tbc1 domain fa...
# 1.10.8.280                     ABC transporter ATPase domain-like
# 1.10.8.290                  uncharacterized protein sp1917 domain
# 1.10.8.300                          putative atpase (yp_676785.1)
# 1.10.8.330                                            PG0816-like
# 1.10.8.340                                            PG0816-like
# 1.10.8.350                                   Bacterial muramidase
# 1.10.8.360                      3,6-anhydro-alpha-l-galactosidase
# 1.10.10.10      Winged helix-like DNA-binding domain superfami...
# 1.10.10.41                     Yeast DNA topoisomerase - domain 1
# 1.10.10.60                                       Homeodomain-like
# 1.10.10.140                     Cytochrome c oxidase, subunit VIb
# 1.10.10.250              Ribosomal protein l11, C-terminal domain
# 1.10.10.400     Polyribonucleotide nucleotidyltransferase, RNA...
# 1.10.10.430         Phosphatase 2c, C-terminal domain suprefamily
# 1.10.10.440                                             FF domain
# 1.10.10.460                            Ribonuclease hii. domain 2
# 1.10.10.470            Maltooligosyl trehalose synthase; domain 4
#                                       ...
# 4.10.1010.10                            Apical membrane antigen 1
# 4.10.1030.10                           Ring box chain a; domain 5
# 4.10.1040.10                                DM DNA-binding domain
# 4.10.1050.10                                       At2g23090-like
# 4.10.1060.10                             Zinc finger, RanBP2-type
# 4.10.1070.10    receptor-binding domain of the bacteriophage t...
# 4.10.1080.10                                    TSP type-3 repeat
# 4.10.1090.10                              Endosialidase, domain 4
# 4.10.1100.10                 Transcription factor, SBP-box domain
# 4.10.1110.10                                 AN1-like zinc finger
# 4.10.1120.10        Retinal cGMP phosphodiesterase, gamma subunit
# 4.10.1130.10             btk motif of tyrosine-protein kinase itk
# 4.10.1140.10    membrane-bound form of the juxtamembrane domai...
# 4.10.1150.10                                   AF2212/PG0164-like
# 4.10.1170.10                MAP kinase activated protein kinase 2
# 4.10.1180.10                                        tm1086 domain
# 4.10.1190.10                      Chlorophyll a-b binding protein
# 4.10.1200.10                               nitrate reductase tail
# 4.10.1210.10                                         Atu1913-like
# 4.10.1220.10                                      EGF-type module
# 4.10.1230.10                            Ecotin, trypsin inhibitor
# 4.10.1240.10    GPCR, family 2, extracellular hormone receptor...
# 4.10.1250.10                      Aminomethyltransferase fragment
# 4.10.1260.10    Scaffolding protein gpd of bacteriophage proca...
# 4.10.1270.10          homoprotocatechuate 2,3-dioxygenase domains
# 4.10.1280.10                              Clostridium neurotoxins
# 4.10.1290.10           Tumor necrosis factor receptor superfamily
# 4.10.1300.10                            Dinoflagellate luciferase
# 4.10.1310.10                     Dinoflagellate luciferase repeat
# 4.10.1330.10          non globular virulence effector SptP domain
# Length: 2317, dtype: object
